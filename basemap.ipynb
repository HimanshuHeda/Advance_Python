# %% [markdown]
# # Import Libraries

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Code for Map

# %%
map = Basemap()
map.drawcoastlines()

# %%
map.fillcontinents(color='coral',lake_color='aqua')
# Out:
# [<matplotlib.patches.Polygon at 0x14369ec3910>,
#  <matplotlib.patches.Polygon at 0x14303f32490>,
#  <matplotlib.patches.Polygon at 0x143041bbc10>,
#  <matplotlib.patches.Polygon at 0x14369ec0710>,
#  <matplotlib.patches.Polygon at 0x14369ec2610>,
#  <matplotlib.patches.Polygon at 0x1436bf82f50>,
#  <matplotlib.patches.Polygon at 0x1435910d590>,
#  <matplotlib.patches.Polygon at 0x143041de2d0>,
#  <matplotlib.patches.Polygon at 0x1436bf57010>,
#  <matplotlib.patches.Polygon at 0x143041d7250>,
#  <matplotlib.patches.Polygon at 0x1436bf3f490>,
#  <matplotlib.patches.Polygon at 0x143041cc350>,
#  <matplotlib.patches.Polygon at 0x1436bf54890>,
#  <matplotlib.patches.Polygon at 0x14369ec2850>,
#  <matplotlib.patches.Polygon at 0x14369e9c890>,
#  <matplotlib.patches.Polygon at 0x1430415a690>,
#  <matplotlib.patches.Polygon at 0x14369e96550>,
#  <matplotlib.patches.Polygon at 0x14303faa350>,
#  <matplotlib.patches.Polygon at 0x14303f21650>,
#  <matplotlib.patches.Polygon at 0x14303d41990>,
#  <matplotlib.patches.Polygon at 0x14369ce8190>,
#  <matplotlib.patches.Polygon at 0x14303e65c10>,
#  <matplotlib.patches.Polygon at 0x1436bf54690>,
#  <matplotlib.patches.Polygon at 0x14303d06590>,
#  <matplotlib.patches.Polygon at 0x14303f6e050>,
#  <matplotlib.patches.Polygon at 0x14304c5a490>,
#  <matplotlib.patches.Polygon at 0x14304c8ab90>,
#  <matplotlib.patches.Polygon at 0x14304c74bd0>,
#  <matplotlib.patches.Polygon at 0x1436bf7a2d0>,
#  <matplotlib.patches.Polygon at 0x14369ee0b90>,
#  <matplotlib.patches.Polygon at 0x143041cecd0>,
#  <matplotlib.patches.Polygon at 0x1436bf96750>,
#  <matplotlib.patches.Polygon at 0x143041cd910>,
#  <matplotlib.patches.Polygon at 0x143041cd250>,
#  <matplotlib.patches.Polygon at 0x143041ab110>,
#  <matplotlib.patches.Polygon at 0x143041cc3d0>,
#  <matplotlib.patches.Polygon at 0x14304c744d0>,
#  <matplotlib.patches.Polygon at 0x1436bf57c10>,
#  <matplotlib.patches.Polygon at 0x1436bf97190>,
#  <matplotlib.patches.Polygon at 0x1436bf970d0>,
#  <matplotlib.patches.Polygon at 0x143041d7710>,
#  <matplotlib.patches.Polygon at 0x1436bfa7c50>,
#  <matplotlib.patches.Polygon at 0x14369ce8c90>,
#  <matplotlib.patches.Polygon at 0x14303f3d7d0>,
#  <matplotlib.patches.Polygon at 0x143041493d0>,
#  <matplotlib.patches.Polygon at 0x14398a00410>,
#  <matplotlib.patches.Polygon at 0x1436bf95b10>,
#  <matplotlib.patches.Polygon at 0x143041ba650>,
#  <matplotlib.patches.Polygon at 0x1436bfc2dd0>,
#  <matplotlib.patches.Polygon at 0x143041bbd10>,
#  <matplotlib.patches.Polygon at 0x1436bfc3cd0>,
#  <matplotlib.patches.Polygon at 0x14369cf4ad0>,
#  <matplotlib.patches.Polygon at 0x1436bf951d0>,
#  <matplotlib.patches.Polygon at 0x143041cd890>,
#  <matplotlib.patches.Polygon at 0x1430412e090>,
#  <matplotlib.patches.Polygon at 0x14369ed6010>,
#  <matplotlib.patches.Polygon at 0x14369ed5cd0>,
#  <matplotlib.patches.Polygon at 0x14303f6cdd0>,
#  <matplotlib.patches.Polygon at 0x143041cd490>,
#  <matplotlib.patches.Polygon at 0x14369e75990>,
#  <matplotlib.patches.Polygon at 0x14369cf6c50>,
#  <matplotlib.patches.Polygon at 0x14369ed4410>,
#  <matplotlib.patches.Polygon at 0x1436bfa7710>,
#  <matplotlib.patches.Polygon at 0x14369ed7e90>,
#  <matplotlib.patches.Polygon at 0x14369e76490>,
#  <matplotlib.patches.Polygon at 0x14369e96110>,
#  <matplotlib.patches.Polygon at 0x14369ed4a90>,
#  <matplotlib.patches.Polygon at 0x14369e94a90>,
#  <matplotlib.patches.Polygon at 0x1436bf57250>,
#  <matplotlib.patches.Polygon at 0x1436bf95910>,
#  <matplotlib.patches.Polygon at 0x1436bf56d10>,
#  <matplotlib.patches.Polygon at 0x1436bf56f90>,
#  <matplotlib.patches.Polygon at 0x14369e77b50>,
#  <matplotlib.patches.Polygon at 0x14369dd7310>,
#  <matplotlib.patches.Polygon at 0x14369e95c90>,
#  <matplotlib.patches.Polygon at 0x14369d5bdd0>,
#  <matplotlib.patches.Polygon at 0x1436bfc2d50>,
#  <matplotlib.patches.Polygon at 0x14369f05b90>,
#  <matplotlib.patches.Polygon at 0x14369ee0610>,
#  <matplotlib.patches.Polygon at 0x14369ce8fd0>,
#  <matplotlib.patches.Polygon at 0x14369dd4e10>,
#  <matplotlib.patches.Polygon at 0x14303fa9d90>,
#  <matplotlib.patches.Polygon at 0x1436bf82a50>,
#  <matplotlib.patches.Polygon at 0x14369d5aad0>,
#  <matplotlib.patches.Polygon at 0x14369d58cd0>,
#  <matplotlib.patches.Polygon at 0x14369d22dd0>,
#  <matplotlib.patches.Polygon at 0x14369cea790>,
#  <matplotlib.patches.Polygon at 0x14369d62810>,
#  <matplotlib.patches.Polygon at 0x1436bfc1890>,
#  <matplotlib.patches.Polygon at 0x14304c21710>,
#  <matplotlib.patches.Polygon at 0x14303f33a50>,
#  <matplotlib.patches.Polygon at 0x14369ee06d0>,
#  <matplotlib.patches.Polygon at 0x14369d58c50>,
#  <matplotlib.patches.Polygon at 0x14369ee3a90>,
#  <matplotlib.patches.Polygon at 0x14369ee3390>,
#  <matplotlib.patches.Polygon at 0x1436bfc2c90>,
#  <matplotlib.patches.Polygon at 0x14369d02c10>,
#  <matplotlib.patches.Polygon at 0x14369d02450>,
#  <matplotlib.patches.Polygon at 0x14369d61650>,
#  <matplotlib.patches.Polygon at 0x14369d01750>,
#  <matplotlib.patches.Polygon at 0x14369ee2850>,
#  <matplotlib.patches.Polygon at 0x14369d003d0>,
#  <matplotlib.patches.Polygon at 0x14304c60d90>,
#  <matplotlib.patches.Polygon at 0x14369d5b750>,
#  <matplotlib.patches.Polygon at 0x14369cf4690>,
#  <matplotlib.patches.Polygon at 0x14369d5a290>,
#  <matplotlib.patches.Polygon at 0x1436bf55590>,
#  <matplotlib.patches.Polygon at 0x1436bfc1990>,
#  <matplotlib.patches.Polygon at 0x14369d5ac10>,
#  <matplotlib.patches.Polygon at 0x14304c7ad90>,
#  <matplotlib.patches.Polygon at 0x14369d02c90>,
#  <matplotlib.patches.Polygon at 0x14303d43f50>,
#  <matplotlib.patches.Polygon at 0x14369d5bc90>,
#  <matplotlib.patches.Polygon at 0x14369c6d910>,
#  <matplotlib.patches.Polygon at 0x1436bf89990>,
#  <matplotlib.patches.Polygon at 0x14369d58610>,
#  <matplotlib.patches.Polygon at 0x14369e94590>,
#  <matplotlib.patches.Polygon at 0x14304c60310>,
#  <matplotlib.patches.Polygon at 0x14369d5be90>,
#  <matplotlib.patches.Polygon at 0x14303d28e90>,
#  <matplotlib.patches.Polygon at 0x14304123e10>,
#  <matplotlib.patches.Polygon at 0x14369ed5650>,
#  <matplotlib.patches.Polygon at 0x14369dd7410>,
#  <matplotlib.patches.Polygon at 0x14369ed48d0>,
#  <matplotlib.patches.Polygon at 0x14369ed4210>,
#  <matplotlib.patches.Polygon at 0x14369e955d0>,
#  <matplotlib.patches.Polygon at 0x14369d5a710>]
